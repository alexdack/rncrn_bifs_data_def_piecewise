# %%
import numpy as np
import tensorflow as tf
import scipy.io
from keras import backend as K
from keras.layers import Activation
from tensorflow.keras.utils import get_custom_objects
from scipy.special import jv

# %%
# define the filename to save the weights of the model as a .mat
filename = 'models/hopf_critical'

# define the interval of the domain for the visible dynamics
lower_limit = 2
upper_limit = 8

step_size = 0.015;
step_size_par = 0.25;

# define the approximate size the small offset parameter in the smooth ReLU
gamma = 1

# define the approximate size the feedback offset parameter in the feedback motif
beta_1 = 1

alpha = 1;

# define the number of hidden species in a single hidden layer
N = 6;

# bifurication center
a = 5;

# define the number of epochs to use in training the model
number_of_epochs = 200

# %%
# define the custom activation function for the training with particular values of the relu_offset
def smooth_max_activation(x):
    return 0.5*(x + K.sqrt(K.square(x)+4*gamma*alpha))/alpha

get_custom_objects().update({'smooth_max_activation': Activation(smooth_max_activation)})


#define data
x1_train = np.arange(lower_limit, upper_limit, step_size, dtype="float32")
x2_train = np.arange(lower_limit, upper_limit, step_size, dtype="float32")

x1v, x2v, x3v = np.meshgrid(x1_train, x2_train, x3_train, indexing='ij')

nx1 = len(x1_train)
nx2 = len(x2_train)
nx3 = len(x3_train)

D = x3v -np.power(x1v-a, 2) -np.power(x2v-a, 2)

g_1 = D*(x1v-a) - (x2v-a)
g_2 = D*(x2v-a) + (x1v-a)

y1_train = (g_1 - beta_1)/x1v
y2_train = (g_2 - beta_1)/x2v

x_train = np.append(np.append(x1v.reshape(-1,1), x2v.reshape(-1,1),axis=1))
y_train = np.append(y1_train.reshape(-1,1), y2_train.reshape(-1,1),axis=1)

# %%
# define a neural network model that corresponds to the asymptotic neural subsytem 
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(2,), name=''),
  tf.keras.layers.Dense(N, activation='smooth_max_activation'),
  tf.keras.layers.Dense(2, activation=None, use_bias=False),
])

# compile model with optimizer and choice of loss function
model.compile(optimizer='adam',
              loss='mse',
              metrics=['mse'])

# %%
# train the neural network model to replicate x_train -> y_train
model.fit(x_train, y_train, epochs=number_of_epochs, validation_split = 0.1)
# Out:
# Epoch 1/200
# 22500/22500 [==============================] - 17s 763us/step - loss: 0.2857 - mse: 0.2857 - val_loss: 1.9761 - val_mse: 1.9761
# Epoch 2/200
# 22500/22500 [==============================] - 18s 781us/step - loss: 0.2849 - mse: 0.2849 - val_loss: 1.9752 - val_mse: 1.9752
# Epoch 3/200
# 22500/22500 [==============================] - 20s 879us/step - loss: 0.2845 - mse: 0.2845 - val_loss: 1.9512 - val_mse: 1.9512
# Epoch 4/200
# 22500/22500 [==============================] - 17s 766us/step - loss: 0.2843 - mse: 0.2843 - val_loss: 1.9264 - val_mse: 1.9264
# Epoch 5/200
#  9924/22500 [============>.................] - ETA: 8s - loss: 0.2824 - mse: 0.2824
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 # train the neural network model to replicate x_train -> y_train
# ----> 2 model.fit(x_train, y_train, epochs=number_of_epochs, validation_split = 0.1)
#
# File ~\AppData\Local\miniconda3\envs\tf\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\miniconda3\envs\tf\lib\site-packages\keras\src\engine\training.py:1733, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1731 callbacks.on_epoch_begin(epoch)
#    1732 with data_handler.catch_stop_iteration():
# -> 1733     for step in data_handler.steps():
#    1734         with tf.profiler.experimental.Trace(
#    1735             "train",
#    1736             epoch_num=epoch,
#    (...)
#    1739             _r=1,
#    1740         ):
#    1741             callbacks.on_train_batch_begin(step)
#
# File ~\AppData\Local\miniconda3\envs\tf\lib\site-packages\keras\src\engine\data_adapter.py:1401, in DataHandler.steps(self)
#    1399 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1400     break
# -> 1401 original_spe = self._steps_per_execution.numpy().item()
#    1402 can_run_full_execution = (
#    1403     original_spe == 1
#    1404     or self._inferred_steps is None
#    1405     or self._inferred_steps - self._current_step >= original_spe
#    1406 )
#    1408 if can_run_full_execution:
#
# File ~\AppData\Local\miniconda3\envs\tf\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:688, in BaseResourceVariable.numpy(self)
#     686 def numpy(self):
#     687   if context.executing_eagerly():
# --> 688     return self.read_value().numpy()
#     689   raise NotImplementedError(
#     690       "numpy() is only available when eager execution is enabled.")
#
# File ~\AppData\Local\miniconda3\envs\tf\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:815, in BaseResourceVariable.read_value(self)
#     806 """Constructs an op which reads the value of this variable.
#     807
#     808 Should be used when there are multiple reads, or when it is desirable to
#    (...)
#     812   The value of the variable.
#     813 """
#     814 with ops.name_scope("Read"):
# --> 815   value = self._read_variable_op()
#     816 # Return an identity so it can get placed on whatever device the context
#     817 # specifies instead of the device where the variable is.
#     818 return array_ops.identity(value)
#
# File ~\AppData\Local\miniconda3\envs\tf\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:794, in BaseResourceVariable._read_variable_op(self, no_copy)
#     792       result = read_and_set_handle(no_copy)
#     793 else:
# --> 794   result = read_and_set_handle(no_copy)
#     796 if not context.executing_eagerly():
#     797   # Note that if a control flow context is active the input of the read op
#     798   # might not actually be the handle. This line bypasses it.
#     799   record.record_operation(
#     800       "ReadVariableOp", [result], [self.handle],
#     801       backward_function=lambda x: [x],
#     802       forward_function=lambda x: [x])
#
# File ~\AppData\Local\miniconda3\envs\tf\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:784, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     782 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     783   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 784 result = gen_resource_variable_ops.read_variable_op(
#     785     self.handle, self._dtype)
#     786 _maybe_set_handle_data(self._dtype, self.handle, result)
#     787 return result
#
# File ~\AppData\Local\miniconda3\envs\tf\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:581, in read_variable_op(resource, dtype, name)
#     579 if tld.is_eager:
#     580   try:
# --> 581     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     582       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     583     return _result
#     584   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# view the model structure, each 'Param' corresponds to at least one rate of reaction in the chemical system
model.summary()

# save the weights of this neural network for use in ODE simulations in MATLAB
first_layer_weights = model.layers[1].get_weights()[0]
first_layer_biases = model.layers[1].get_weights()[1]
output_layer_weights = model.layers[2].get_weights()[0]
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#   (Flatten)                  (None, 3)                 0
#
#  dense (Dense)               (None, 7)                 28
#
#  dense_1 (Dense)             (None, 2)                 14
#
# =================================================================
# Total params: 42 (168.00 Byte)
# Trainable params: 42 (168.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
scipy.io.savemat(filename+'.mat', {'first_layer_weights':first_layer_weights, 
                                   'first_layer_biases':first_layer_biases, 
                                   'output_layer_weights':output_layer_weights,
                                   'gamma': gamma,
                                   'beta': beta_1,
                                   'alpha': alpha
                                  })
