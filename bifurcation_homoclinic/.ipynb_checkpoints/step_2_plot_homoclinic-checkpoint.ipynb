# %%
import numpy as np
import tensorflow as tf
import scipy.io
from keras import backend as K
from keras.layers import Activation
from tensorflow.keras.utils import get_custom_objects
from scipy.special import jv
import matplotlib.pyplot as plt
import matplotlib as mpl
from cycler import cycler
from scipy.integrate import solve_ivp

# %%
# define the filename to save the weights of the model as a .mat
filename = 'models/example_homoclinic'

# %%
#define data
x1_train = np.arange(xlower_limit, xupper_limit, step_size, dtype="float32")
x2_train = np.arange(ylower_limit, yupper_limit, step_size, dtype="float32")
x3_train = np.arange(param_lower_limit, param_upper_limit, step_size_par, dtype="float32")
x1v, x2v, x3v = np.meshgrid(x1_train, x2_train, x3_train, indexing='ij')

nx1 = len(x1_train)
nx2 = len(x2_train)
nx3 = len(x3_train)


g_1 = (x3v-(4/5))*(x1v-a)+(x2v-a)-(6/5)*(x1v-a)*(x2v-a)+(3/2)*pow((x2v-a),2)
g_2 = (x1v-a) -(4/5)*(x2v-a) - (4/5)*pow((x2v-a),2)

y1_train = (g_1 - beta_1)/x1v
y2_train = (g_2 - beta_1)/x2v

x_train = np.append(np.append(x1v.reshape(-1,1), x2v.reshape(-1,1),axis=1), x3v.reshape(-1,1),axis=1)
y_train = np.append(y1_train.reshape(-1,1), y2_train.reshape(-1,1),axis=1)

# %%
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['font.size'] = 30
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['font.serif'] = 'Times New Roman'
mpl.rcParams['mathtext.fontset'] = 'cm'
mpl.rcParams['font.family'] = 'serif'
plt.rcParams['axes.prop_cycle'] = cycler(alpha=[1])
mpl.rcParams['figure.figsize'] = [20 , 12]
mpl.rcParams['text.usetex'] = False
mpl.rcParams['legend.edgecolor'] = 'k'
mpl.rcParams['legend.framealpha'] = 1
mpl.rcParams['legend.fancybox'] = False
ColList = ['#1F13FF','#FF00D0', '#2A2A72', '#A9A9A9']
density =1.5

lower_limit = 3;
upper_limit = 7;

mu = -0.1
args_tup = (a,mu)
tFinal = 250;

inits = [3.5, 6.0]#[3.5, 6.0305];
sol_normal_form = solve_ivp(homoclinic_bifurcation, [0, tFinal], inits, args=args_tup, rtol=10e-8)
time_scale = 0.0075

mu_rncrn = 0
inits_RNCRN_shift = [3.5, 5.825]; #[3.5, 5.85];
args_rncrn = (beta_1, gamma, time_scale, first_layer_weights, output_layer_weights, first_layer_biases, 1, mu_rncrn)
inits_rncrn = list(np.append(inits_RNCRN_shift, np.zeros((1,N))))
sol_rncrn = solve_ivp(rncrn_simulation, [0, tFinal], inits_rncrn, args=args_rncrn, rtol=10e-8)



fig, axs = plt.subplots(1,2)
vis_step = 0.25;
x1_train = np.arange(lower_limit, upper_limit, vis_step, dtype="float32")
x2_train = np.arange(lower_limit, upper_limit+1, vis_step, dtype="float32")
x3_train = np.array([mu])

x1v, x2v, x3v = np.meshgrid(x1_train, x2_train, x3_train, indexing='ij')

nx1 = len(x1_train)
nx2 = len(x2_train)
nx3 = len(x3_train)

g_1 = (x3v-(4/5))*(x1v-a)+(x2v-a)-(6/5)*(x1v-a)*(x2v-a)+(3/2)*pow((x2v-a),2)
g_2 = (x1v-a) -(4/5)*(x2v-a) - (4/5)*pow((x2v-a),2)

res_true_1 = np.transpose(g_1.reshape(g_1.shape[0],g_1.shape[1]))
res_true_2 = np.transpose(g_2.reshape(g_1.shape[0],g_1.shape[1]))
axs[0].streamplot(x1_train, x2_train,res_true_1,res_true_2,  arrowstyle='-|>', color=ColList[3], linewidth=2, density=2)
axs[0].set_xlim(lower_limit+0.5, upper_limit-0.5)
axs[0].set_ylim(lower_limit+0.5, upper_limit-0.5)
axs[0].plot(sol_normal_form.y[0,:], sol_normal_form.y[1,:], color=ColList[0], )
axs[0].set_title('Target ($\mu=0$)')
axs[0].set_xlabel('$x_1$')
axs[0].set_ylabel('$x_2$')
circle_blue  = plt.Circle((a, a), 0.025, color=ColList[0])
axs[0].add_patch(circle_blue)
circle_blue2  = plt.Circle((4.84, 4.36), 0.025, color=ColList[0])
axs[0].add_patch(circle_blue2)
axs[0].set_xlim(4,6)
axs[0].set_ylim(3.5, 6)

x_train =  np.concatenate( (x1v.reshape(-1,1), x2v.reshape(-1,1), x3v.reshape(-1,1)), axis=1)
y_out = model.predict(x_train);
U_out = y_out.reshape(g_1.shape[0], g_1.shape[1], 2)

res_1 =  beta_1 + np.transpose(np.multiply(U_out[:,:,0], x1v.reshape( g_1.shape[0], g_1.shape[1])))
res_2 =  beta_1 + np.transpose(np.multiply(U_out[:,:,1], x2v.reshape(g_2.shape[0], g_2.shape[1])))
axs[1].streamplot(x1_train, x2_train, res_1, res_2,  arrowstyle='-|>', color=ColList[3], linewidth=2, density=2)
axs[1].plot(sol_rncrn.y[0,:], sol_rncrn.y[1,:], color=ColList[1], )

axs[1].set_xlim(lower_limit+0.5, upper_limit-0.5)
axs[1].set_ylim(lower_limit+0.5, upper_limit-0.5)
axs[1].set_xlabel('$x_1$')
axs[1].set_ylabel('$x_2$')
axs[1].set_title('RNCRN ($\mu=0$)')
circle_pink  = plt.Circle((a, a), 0.025, color=ColList[1])
circle_pink2  = plt.Circle((4.84, 4.36), 0.025, color=ColList[1])

axs[1].add_patch(circle_pink)
axs[1].add_patch(circle_pink2)
axs[1].set_xlim(4,6)
axs[1].set_ylim(3.5, 6)

plt.show()
fig.savefig('figures/homoclinic_orbit.pdf', bbox_inches='tight')
# Out:
# 10/10 [==============================] - 0s 733us/step

# %%
lower_limit = 3;
upper_limit = 7;

tFinal = 250;
inits = [3.5, 6.0];
args_tup = (a,-0.1)
sol_1= solve_ivp(homoclinic_bifurcation, [0, tFinal], inits, args=args_tup, rtol=10e-8)

inits = [3.5, 5.6];
args_tup = (a,-0.1)
sol_1b= solve_ivp(homoclinic_bifurcation, [0, tFinal], inits, args=args_tup, rtol=10e-8)


args_tup = (a,0)
inits = [3.5, 6.0305];
sol_2= solve_ivp(homoclinic_bifurcation, [0, tFinal], inits, args=args_tup, rtol=10e-8)

args_tup = (a,0.1)
inits = [3.5, 6.0305];
sol_3= solve_ivp(homoclinic_bifurcation, [0, tFinal], inits, args=args_tup, rtol=10e-8)

inits = [4.8, 4.3];
sol_3b= solve_ivp(homoclinic_bifurcation, [0, tFinal], inits, args=args_tup, rtol=10e-8)

time_scale = 0.0075
inits_RNCRN_shift = [3.5, 5.825]; 
inits_rncrn = list(np.append(inits_RNCRN_shift, np.zeros((1,N))))
args_rncrn = (beta_1, gamma, time_scale, first_layer_weights, output_layer_weights, first_layer_biases, 1, -0.1)
sol_rncrn_1 = solve_ivp(rncrn_simulation, [0, tFinal], inits_rncrn, args=args_rncrn, rtol=10e-8)


inits_RNCRN_shift = [3.5, 5.4]; 
inits_rncrn = list(np.append(inits_RNCRN_shift, np.zeros((1,N))))
args_rncrn = (beta_1, gamma, time_scale, first_layer_weights, output_layer_weights, first_layer_biases, 1, -0.1)
sol_rncrn_1b = solve_ivp(rncrn_simulation, [0, tFinal], inits_rncrn, args=args_rncrn, rtol=10e-8)

args_rncrn = (beta_1, gamma, time_scale, first_layer_weights, output_layer_weights, first_layer_biases, 1, 0)
inits_RNCRN_shift = [3.5, 5.79]; 
inits_rncrn = list(np.append(inits_RNCRN_shift, np.zeros((1,N))))
sol_rncrn_2 = solve_ivp(rncrn_simulation, [0, tFinal], inits_rncrn, args=args_rncrn, rtol=10e-8)

args_rncrn = (beta_1, gamma, time_scale, first_layer_weights, output_layer_weights, first_layer_biases, 1, 0.1)
inits_RNCRN_shift = [3.5, 5.825]; 
inits_rncrn = list(np.append(inits_RNCRN_shift, np.zeros((1,N))))

sol_rncrn_3 = solve_ivp(rncrn_simulation, [0, tFinal], inits_rncrn, args=args_rncrn, rtol=10e-8)
inits_RNCRN_shift = [4.8,4.2]; 
inits_rncrn = list(np.append(inits_RNCRN_shift, np.zeros((1,N))))

sol_rncrn_3b = solve_ivp(rncrn_simulation, [0, tFinal], inits_rncrn, args=args_rncrn, rtol=10e-8)

# %%
lower_limit = 3
upper_limit = 7

vis_step = 0.25;
x1_train = np.arange(lower_limit, upper_limit, vis_step, dtype="float32")
x2_train = np.arange(lower_limit, upper_limit, vis_step, dtype="float32")
x3_train = np.array([mu])

x1v, x2v, x3v = np.meshgrid(x1_train, x2_train, x3_train, indexing='ij')

nx1 = len(x1_train)
nx2 = len(x2_train)
nx3 = len(x3_train)

mu = -0.1
x3_train = np.array([mu])
x1v, x2v, x3v = np.meshgrid(x1_train, x2_train, x3_train, indexing='ij')
g_1 = (x3v-(4/5))*(x1v-a)+(x2v-a)-(6/5)*(x1v-a)*(x2v-a)+(3/2)*pow((x2v-a),2)
g_2 = (x1v-a) -(4/5)*(x2v-a) - (4/5)*pow((x2v-a),2)
target_vf_x1_1 = np.transpose(g_1.reshape(g_1.shape[0],g_1.shape[1]))
target_vf_x2_1 = np.transpose(g_2.reshape(g_1.shape[0],g_1.shape[1]))

x_train =  np.concatenate( (x1v.reshape(-1,1), x2v.reshape(-1,1), x3v.reshape(-1,1)), axis=1)
y_out = model.predict(x_train);
U_out = y_out.reshape(g_1.shape[0], g_1.shape[1], 2)

res_x1_1 =  beta_1 + np.transpose(np.multiply(U_out[:,:,0], x1v.reshape( g_1.shape[0], g_1.shape[1])))
res_x2_1 =  beta_1 + np.transpose(np.multiply(U_out[:,:,1], x2v.reshape(g_2.shape[0], g_2.shape[1])))

mu = 0
x3_train = np.array([mu])
x1v, x2v, x3v = np.meshgrid(x1_train, x2_train, x3_train, indexing='ij')
g_1 = (x3v-(4/5))*(x1v-a)+(x2v-a)-(6/5)*(x1v-a)*(x2v-a)+(3/2)*pow((x2v-a),2)
g_2 = (x1v-a) -(4/5)*(x2v-a) - (4/5)*pow((x2v-a),2)
target_vf_x1_2 = np.transpose(g_1.reshape(g_1.shape[0],g_1.shape[1]))
target_vf_x2_2 = np.transpose(g_2.reshape(g_1.shape[0],g_1.shape[1]))

x_train =  np.concatenate( (x1v.reshape(-1,1), x2v.reshape(-1,1), x3v.reshape(-1,1)), axis=1)
y_out = model.predict(x_train);
U_out = y_out.reshape(g_1.shape[0], g_1.shape[1], 2)

res_x1_2 =  beta_1 + np.transpose(np.multiply(U_out[:,:,0], x1v.reshape( g_1.shape[0], g_1.shape[1])))
res_x2_2 =  beta_1 + np.transpose(np.multiply(U_out[:,:,1], x2v.reshape(g_2.shape[0], g_2.shape[1])))


mu = 0.1
x3_train = np.array([mu])
x1v, x2v, x3v = np.meshgrid(x1_train, x2_train, x3_train, indexing='ij')
g_1 = (x3v-(4/5))*(x1v-a)+(x2v-a)-(6/5)*(x1v-a)*(x2v-a)+(3/2)*pow((x2v-a),2)
g_2 = (x1v-a) -(4/5)*(x2v-a) - (4/5)*pow((x2v-a),2)
target_vf_x1_3 = np.transpose(g_1.reshape(g_1.shape[0],g_1.shape[1]))
target_vf_x2_3 = np.transpose(g_2.reshape(g_1.shape[0],g_1.shape[1]))

x_train =  np.concatenate( (x1v.reshape(-1,1), x2v.reshape(-1,1), x3v.reshape(-1,1)), axis=1)
y_out = model.predict(x_train);
U_out = y_out.reshape(g_1.shape[0], g_1.shape[1], 2)

res_x1_3 =  beta_1 + np.transpose(np.multiply(U_out[:,:,0], x1v.reshape( g_1.shape[0], g_1.shape[1])))
res_x2_3 =  beta_1 + np.transpose(np.multiply(U_out[:,:,1], x2v.reshape(g_2.shape[0], g_2.shape[1])))
# Out:
# ...
# 8/8 [==============================] - 0s 725us/step

# %%
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['font.size'] = 30
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['font.serif'] = 'Times New Roman'
mpl.rcParams['mathtext.fontset'] = 'cm'
mpl.rcParams['font.family'] = 'serif'
plt.rcParams['axes.prop_cycle'] = cycler(alpha=[1])
mpl.rcParams['figure.figsize'] = [20 , 12]
mpl.rcParams['text.usetex'] = False
mpl.rcParams['legend.edgecolor'] = 'k'
mpl.rcParams['legend.framealpha'] = 1
mpl.rcParams['legend.fancybox'] = False
ColList = ['#1F13FF','#FF00D0', '#2A2A72', '#A9A9A9']

circle_blue  = plt.Circle((a, a), 0.025, color=ColList[0])
circle_blue2  = plt.Circle((4.84, 4.36), 0.025, color=ColList[0])
circle_pink  = plt.Circle((a, a), 0.025, color=ColList[1])
circle_pink2  = plt.Circle((4.84, 4.36), 0.025, color=ColList[1])


fig, axs = plt.subplots(2,3)
axs[0,0].streamplot(x1_train, x2_train,target_vf_x1_1,target_vf_x2_1,  arrowstyle='-|>', color=ColList[3], linewidth=2, density=2)
axs[0,0].set_xlim(lower_limit+0.5, upper_limit-0.5)
axs[0,0].set_ylim(lower_limit+0.5, upper_limit-0.5)
axs[0,0].plot(sol_1.y[0,:], sol_1.y[1,:], color=ColList[0], )
axs[0,0].plot(sol_1b.y[0,:], sol_1b.y[1,:], color=ColList[0], )
axs[0,0].set_title('Target: $\mu=-1/10$')
axs[0,0].set_xlabel('$x_1$')
axs[0,0].set_ylabel('$x_2$')
axs[0,0].add_patch(circle_blue)
axs[0,0].add_patch(circle_blue2)
axs[0,0].set_xlim(4,6)
axs[0,0].set_ylim(3.5, 6)

axs[0,1].streamplot(x1_train, x2_train,target_vf_x1_2,target_vf_x2_2,  arrowstyle='-|>', color=ColList[3], linewidth=2, density=2)
axs[0,1].set_xlim(lower_limit+0.5, upper_limit-0.5)
axs[0,1].set_ylim(lower_limit+0.5, upper_limit-0.5)
axs[0,1].plot(sol_2.y[0,:], sol_2.y[1,:], color=ColList[0], )
axs[0,1].set_title('Target: $\mu=0$')
axs[0,1].set_xlabel('$x_1$')
axs[0,1].set_ylabel('$x_2$')
axs[0,1].set_xlim(4,6)
axs[0,1].set_ylim(3.5, 6)

axs[0,2].streamplot(x1_train, x2_train,target_vf_x1_3,target_vf_x2_3,  arrowstyle='-|>', color=ColList[3], linewidth=2, density=2)
axs[0,2].set_xlim(lower_limit+0.5, upper_limit-0.5)
axs[0,2].set_ylim(lower_limit+0.5, upper_limit-0.5)
axs[0,2].plot(sol_3.y[0,:], sol_3.y[1,:], color=ColList[0], )
axs[0,2].plot(sol_3b.y[0,:], sol_3b.y[1,:], color=ColList[0], )
axs[0,2].set_title('Target: $\mu=1/10$')
axs[0,2].set_xlabel('$x_1$')
axs[0,2].set_ylabel('$x_2$')
axs[0,2].set_xlim(4,6)
axs[0,2].set_ylim(3.5, 6)


axs[1,0].streamplot(x1_train, x2_train, res_x1_1, res_x2_1,  arrowstyle='-|>', color=ColList[3], linewidth=2, density=2)
axs[1,0].plot(sol_rncrn_1.y[0,:], sol_rncrn_1.y[1,:], color=ColList[1], )
axs[1,0].plot(sol_rncrn_1b.y[0,:], sol_rncrn_1b.y[1,:], color=ColList[1], )
axs[1,0].set_xlim(lower_limit+0.5, upper_limit-0.5)
axs[1,0].set_ylim(lower_limit+0.5, upper_limit-0.5)
axs[1,0].set_xlabel('$x_1$')
axs[1,0].set_ylabel('$x_2$')
axs[1,0].set_title('RNCRN: $\mu=-1/10$')
axs[1,0].add_patch(circle_pink)
axs[1,0].add_patch(circle_pink2)
axs[1,0].set_xlim(4,6)
axs[1,0].set_ylim(3.5, 6)


axs[1,1].streamplot(x1_train, x2_train, res_x1_2, res_x2_2,  arrowstyle='-|>', color=ColList[3], linewidth=2, density=2)
axs[1,1].plot(sol_rncrn_2.y[0,:], sol_rncrn_2.y[1,:], color=ColList[1], )
axs[1,1].set_xlim(lower_limit+0.5, upper_limit-0.5)
axs[1,1].set_ylim(lower_limit+0.5, upper_limit-0.5)
axs[1,1].set_xlabel('$x_1$')
axs[1,1].set_ylabel('$x_2$')
axs[1,1].set_title('RNCRN: $\mu=0$')
axs[1,1].set_xlim(4,6)
axs[1,1].set_ylim(3.5, 6)


axs[1,2].streamplot(x1_train, x2_train, res_x1_3, res_x2_3,  arrowstyle='-|>', color=ColList[3], linewidth=2, density=2)
axs[1,2].plot(sol_rncrn_3.y[0,:], sol_rncrn_3.y[1,:], color=ColList[1], )
axs[1,2].plot(sol_rncrn_3b.y[0,:], sol_rncrn_3b.y[1,:], color=ColList[1], )
axs[1,2].set_xlim(lower_limit+0.5, upper_limit-0.5)
axs[1,2].set_ylim(lower_limit+0.5, upper_limit-0.5)
axs[1,2].set_xlabel('$x_1$')
axs[1,2].set_ylabel('$x_2$')
axs[1,2].set_title('RNCRN: $\mu=1/10$')
axs[1,2].set_xlim(4,6)
axs[1,2].set_ylim(3.5, 6)
plt.tight_layout()
plt.show()
fig.savefig('figures/homoclinic_bifurcation.pdf', bbox_inches='tight')

# %%
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['font.size'] = 30
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['font.serif'] = 'Times New Roman'
mpl.rcParams['mathtext.fontset'] = 'cm'
mpl.rcParams['font.family'] = 'serif'
plt.rcParams['axes.prop_cycle'] = cycler(alpha=[1])
mpl.rcParams['figure.figsize'] = [20 , 6]
mpl.rcParams['text.usetex'] = False
mpl.rcParams['legend.edgecolor'] = 'k'
mpl.rcParams['legend.framealpha'] = 1
mpl.rcParams['legend.fancybox'] = False
ColList = ['#1F13FF','#FF00D0', '#2A2A72', '#A9A9A9']

circle_blue  = plt.Circle((a, a), 0.025, color=ColList[0])
circle_blue2  = plt.Circle((4.84, 4.36), 0.025, color=ColList[0])
circle_pink  = plt.Circle((a, a), 0.025, color=ColList[1])
circle_pink2  = plt.Circle((4.84, 4.36), 0.025, color=ColList[1])


fig, axs = plt.subplots(1,3)
axs[0].set_xlim(lower_limit+0.5, upper_limit-0.5)
axs[0].set_ylim(lower_limit+0.5, upper_limit-0.5)
axs[0].plot(sol_1.y[0,:], sol_1.y[1,:], color=ColList[0], )
axs[0].plot(sol_1b.y[0,:], sol_1b.y[1,:], color=ColList[0], )
axs[0].add_patch(circle_blue)
axs[0].add_patch(circle_blue2)
axs[0].set_xlim(4,6)
axs[0].set_ylim(3.5, 6)

axs[1].set_xlim(lower_limit+0.5, upper_limit-0.5)
axs[1].set_ylim(lower_limit+0.5, upper_limit-0.5)
axs[1].plot(sol_2.y[0,:], sol_2.y[1,:], color=ColList[0], )
axs[1].set_xlim(4,6)
axs[1].set_ylim(3.5, 6)

axs[2].set_xlim(lower_limit+0.5, upper_limit-0.5)
axs[2].set_ylim(lower_limit+0.5, upper_limit-0.5)
axs[2].plot(sol_3.y[0,:], sol_3.y[1,:], color=ColList[0], )
axs[2].plot(sol_3b.y[0,:], sol_3b.y[1,:], color=ColList[0], )

axs[2].set_xlim(4,6)
axs[2].set_ylim(3.5, 6)


axs[0].streamplot(x1_train, x2_train, res_x1_1, res_x2_1,  arrowstyle='-|>', color=ColList[3], linewidth=2, density=2)
axs[0].plot(sol_rncrn_1.y[0,:], sol_rncrn_1.y[1,:], color=ColList[1], )
axs[0].plot(sol_rncrn_1b.y[0,:], sol_rncrn_1b.y[1,:], color=ColList[1], )
axs[0].set_xlim(lower_limit+0.5, upper_limit-0.5)
axs[0].set_ylim(lower_limit+0.5, upper_limit-0.5)
axs[0].set_xlabel('$x_1$')
axs[0].set_ylabel('$x_2$')
axs[0].set_title('$\lambda=-1/10$')
axs[0].add_patch(circle_pink)
axs[0].add_patch(circle_pink2)
axs[0].set_xlim(4,6)
axs[0].set_ylim(3.5, 6)


axs[1].streamplot(x1_train, x2_train, res_x1_2, res_x2_2,  arrowstyle='-|>', color=ColList[3], linewidth=2, density=2)
axs[1].plot(sol_rncrn_2.y[0,:], sol_rncrn_2.y[1,:], color=ColList[1], )
axs[1].set_xlim(lower_limit+0.5, upper_limit-0.5)
axs[1].set_ylim(lower_limit+0.5, upper_limit-0.5)
axs[1].set_xlabel('$x_1$')
axs[1].set_ylabel('$x_2$')
axs[1].set_title('$\lambda=0$')
axs[1].set_xlim(4,6)
axs[1].set_ylim(3.5, 6)


axs[2].streamplot(x1_train, x2_train, res_x1_3, res_x2_3,  arrowstyle='-|>', color=ColList[3], linewidth=2, density=2)
axs[2].plot(sol_rncrn_3.y[0,:], sol_rncrn_3.y[1,:], color=ColList[1], )
axs[2].plot(sol_rncrn_3b.y[0,:], sol_rncrn_3b.y[1,:], color=ColList[1], )
axs[2].set_xlim(lower_limit+0.5, upper_limit-0.5)
axs[2].set_ylim(lower_limit+0.5, upper_limit-0.5)
axs[2].set_xlabel('$x_1$')
axs[2].set_ylabel('$x_2$')
axs[2].set_title('$\lambda=1/10$')
axs[2].set_xlim(4,6)
axs[2].set_ylim(3.5, 6)
plt.tight_layout()
plt.show()
fig.savefig('figures/homoclinic_bifurcation.svg', bbox_inches='tight')
